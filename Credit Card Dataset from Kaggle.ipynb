# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# converting the dataset into a dataframe
data = pd.read_csv("CC GENERAL.csv")
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
# Displaying the first and last 10 sample

# %%
data.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# ...

# %%
data.tail(10)
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8940  C19181   130.838554           1.000000     591.24              0.00
# 8941  C19182  5967.475270           0.833333     214.55              0.00
# 8942  C19183    40.829749           1.000000     113.28              0.00
# 8943  C19184     5.871712           0.500000      20.90             20.90
# 8944  C19185   193.571722           0.833333    1012.73           1012.73
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8940                  591.24      0.000000             1.000000
# ...

# %%
# Displaying the column names

# %%
data.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
data.shape
# Out:
# (8950, 18)

# %%
# Columns with missing values

# %%
data.isnull().sum().sort_values(ascending=False).head()   # sortingthe values makes the result zero
# Out:
# MINIMUM_PAYMENTS       313
# CREDIT_LIMIT             1
# TENURE                   0
# PURCHASES_FREQUENCY      0
# BALANCE                  0
# dtype: int64

# %%
# using seaborn to visualize the relationship

# %%
sns.scatterplot(x='BALANCE',y='CREDIT_LIMIT',data=data)
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='CREDIT_LIMIT'>

# %%
# this scatterplot shows that the more your bank balance, the more credit limit you have.... 
#It also shows that there are many outliers in this dataset due to other factors like balance frequency,

# %%
sns.scatterplot(x='PURCHASES',y='BALANCE',data=data)
# Out:
# <AxesSubplot:xlabel='PURCHASES', ylabel='BALANCE'>

# %%
# this scatterplot shows that more customers made purchases less than #20,000

# %%
sns.pairplot(data)
